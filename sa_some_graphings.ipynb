# %%
import pandas as pd

# %%
import numpy as np

# %%
import seaborn as sns

# %%
df_everything_stats_sa88m2 = pd.read_csv('sa88m2_021225_everything_stats.csv')

# %%
df_everything_stats_sa88m2 = df_everything_stats_sa88m2.reset_index(drop=True)

# %%
df_everything_stats_sa88m2
# Out:
#     Unnamed: 0 Arm Entry   Duration  Entry Latency  Exit Latency  \
# 0            0         A  21.233333       0.033333      2.066667
# 1            1         D  13.166667       1.300000      1.266667
# 2            2         B   7.466667       0.566667      0.733333
# 3            3         D   6.933333       0.800000      0.766667
# 4            4         C   8.533333       0.633333      0.700000
# 5            5         A   7.133333       0.533333      0.733333
# 6            6         E   7.700000       0.633333      0.933333
# 7            7         D   7.533333       0.566667      0.833333
# 8            8         B   6.033333       0.466667      0.533333
# 9            9         A   6.933333       0.466667      0.566667
# 10          10         E   5.300000       0.433333      0.700000
# 11          11         C   6.866667       0.566667      0.500000
# 12          12         B   5.166667       0.500000      0.566667
# ...

# %%
sns.histplot(df_everything_stats_sa88m2['Duration'], bins = 20)
# Out:
# C:\Users\Josue Regalado\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Duration', ylabel='Count'>

# %%
sns.histplot(df_everything_stats_sa88m2['Choice Output'], bins = 5, discrete = True)
# Out:
# C:\Users\Josue Regalado\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Choice Output', ylabel='Count'>

# %%
sns.histplot(df_everything_stats_sa88m2['Arm Entry'], bins = 5, discrete = True)
# Out:
# C:\Users\Josue Regalado\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Arm Entry', ylabel='Count'>

# %%
sns.lineplot(df_everything_stats_sa88m2['Choice Output'])
# Out:
# C:\Users\Josue Regalado\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Josue Regalado\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: ylabel='Choice Output'>

# %%
sns.lineplot(df_everything_stats_sa88m2['Arm Entry'])
# Out:
# C:\Users\Josue Regalado\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Josue Regalado\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: ylabel='Arm Entry'>

# %%
sns.scatterplot(data = df_everything_stats_sa88m2, x = "Duration", y = "Arm Nose Movement", hue = "Choice Output", style = "Arm Entry")
# Out:
# <Axes: xlabel='Duration', ylabel='Arm Nose Movement'>

# %%
sns.catplot(data = df_everything_stats_sa88m2, x = "Arm Nose Velocity", y = "Arm Entry", hue = "Choice Output")
# Out:
# C:\Users\Josue Regalado\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Josue Regalado\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.heatmap(

# %%
df_everything_stats_sa190m1 = pd.read_csv('sa190m1_021425_everything_stats.csv')

# %%
df_everything_stats_sa190m1
# Out:
#     Unnamed: 0 Arm Entry   Duration  Entry Latency  Exit Latency  \
# 0            0         E  10.733333       0.033333      0.833333
# 1            1         B  13.700000       1.700000      0.766667
# 2            2         E  26.400000       2.133333      0.700000
# 3            3         B  11.366667       1.233333      0.533333
# 4            4         D   8.066667       0.700000      0.800000
# 5            5         A   2.800000       0.700000      1.600000
# 6            6         D   6.166667       0.600000      0.500000
# 7            7         A   5.933333       0.500000      0.533333
# 8            8         C   6.133333       0.833333      1.200000
# 9            9         D   4.600000       0.666667      0.466667
# 10          10         A   4.833333       0.566667      0.533333
# 11          11         B  10.466667       0.566667      0.466667
# 12          12         D   5.633333       0.500000      0.500000
# ...

# %%
sns.histplot(df_everything_stats_sa190m1['Duration'], bins = 20)
# Out:
# C:\Users\Josue Regalado\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Duration', ylabel='Count'>

# %%
sns.histplot(df_everything_stats_sa190m1['Choice Output'], bins = 5, discrete = True)
# Out:
# C:\Users\Josue Regalado\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Choice Output', ylabel='Count'>

# %%
sns.histplot(df_everything_stats_sa190m1['Arm Entry'], bins = 5, discrete = True)
# Out:
# C:\Users\Josue Regalado\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Arm Entry', ylabel='Count'>

# %%
sns.lineplot(df_everything_stats_sa190m1['Choice Output'])
# Out:
# C:\Users\Josue Regalado\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Josue Regalado\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: ylabel='Choice Output'>

# %%
sns.lineplot(df_everything_stats_sa190m1['Arm Entry'])
# Out:
# C:\Users\Josue Regalado\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Josue Regalado\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: ylabel='Arm Entry'>

# %%
sns.scatterplot(data = df_everything_stats_sa190m1, x = "Duration", y = "Arm Nose Movement", hue = "Choice Output", style = "Arm Entry")
# Out:
# <Axes: xlabel='Duration', ylabel='Arm Nose Movement'>

# %%
sns.catplot(data = df_everything_stats_sa190m1, x = "Duration", y = "Arm Entry", hue = "Choice Output")
# Out:
# C:\Users\Josue Regalado\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Josue Regalado\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.displot(data=df_everything_stats_sa190m1, x="Duration", kind="kde")
sns.displot(data=df_everything_stats_sa190m1, x="Entry Latency", kind="kde")
# Out:
# C:\Users\Josue Regalado\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Josue Regalado\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.catplot(data=df_everything_stats_sa190m1, x="Current Coeff Time Proportional", y="Choice Output", kind="box")

# %%
df_everything_stats_sa190m1['Choice Output'] = df_everything_stats_sa190m1['Choice Output'].astype("string")

# %%
df_everything_stats_sa190m1['Choice Output']
# Out:
# 0     1
# 1     2
# 2     2
# 3     2
# 4     3
# 5     4
# 6     2
# 7     2
# 8     3
# 9     3
# 10    3
# 11    4
# 12    3
# 13    4
# 14    3
# 15    3
# 16    4
# 17    5
# 18    3
# 19    4
# 20    5
# 21    4
# 22    2
# 23    2
# 24    3
# 25    3
# 26    3
# 27    3
# 28    4
# Name: Choice Output, dtype: string

# %%
import polars as pl

# %%
pl.Config.set_fmt_str_lengths(20)
# Out:
# polars.config.Config

# %%
import polars.selectors as cs

# %%
df_sa190m1_pls = pl.read_csv('sa190m1_021425_everything_stats.csv')

# %%
summary_sa190m1 = df_sa190m1_pls.select(cs.numeric()).describe()

# %%
summary_sa190m1
# Out:
# shape: (9, 19)
# ┌────────────┬──────────┬───────────┬──────────┬───┬────────────────┬────────────────┬────────────────┬────────────────┐
# │ statistic  ┆          ┆ Duration  ┆ Entry    ┆ … ┆ Lagged 2 Coeff ┆ Current Coeff  ┆ Lagged 2 Time  ┆ Choice Output  │
# │ ---        ┆ ---      ┆ ---       ┆ Latency  ┆   ┆ ---            ┆ Time P…        ┆ Propor…        ┆ ---            │
# │ str        ┆ f64      ┆ f64       ┆ ---      ┆   ┆ f64            ┆ ---            ┆ ---            ┆ f64            │
# │            ┆          ┆           ┆ f64      ┆   ┆                ┆ f64            ┆ f64            ┆                │
# ╞════════════╪══════════╪═══════════╪══════════╪═══╪════════════════╪════════════════╪════════════════╪════════════════╡
# │ count      ┆ 29.0     ┆ 29.0      ┆ 29.0     ┆ … ┆ 29.0           ┆ 29.0           ┆ 29.0           ┆ 29.0           │
# ...

# %%
'''
create lagging columns
'''

lagged_df_everything_stats_sa190m1 = df_sa190m1_pls.select(
    "Duration", 
    *[pl.col("Duration").shift(i).alias(f"lagged_{i}_duration") for i in [1,2,3,4]],
    "Entry Latency", 
    *[pl.col("Entry Latency").shift(i).alias(f"lagged_{i}_entry_lat") for i in [1,2,3,4]],
    "Exit Latency", 
    *[pl.col("Exit Latency").shift(i).alias(f"lagged_{i}_exit_lat") for i in [1,2,3,4]], 
    "Arm Nose Movement", 
    *[pl.col("Arm Nose Movement").shift(i).alias(f"lagged_{i}_arm_nose_mov") for i in [1,2,3,4]],
    "Arm Nose Velocity", 
    *[pl.col("Arm Nose Velocity").shift(i).alias(f"lagged_{i}_arm_nose_vel") for i in [1,2,3,4]],
    "Arm Tail Movement", 
    *[pl.col("Arm Tail Movement").shift(i).alias(f"lagged_{i}_arm_tail_mov") for i in [1,2,3,4]],
    "Arm Tail Velocity", 
    *[pl.col("Arm Tail Velocity").shift(i).alias(f"lagged_{i}_arm_tail_vel") for i in [1,2,3,4]],
    "Middle Duration", 
    *[pl.col("Middle Duration").shift(i).alias(f"lagged_{i}_mid_duration") for i in [1,2,3,4]],
    "Middle Nose Movement", 
    *[pl.col("Middle Nose Movement").shift(i).alias(f"lagged_{i}_mid_nose_mov") for i in [1,2,3,4]],
    "Middle Nose Velocity", 
    *[pl.col("Middle Nose Velocity").shift(i).alias(f"lagged_{i}_mid_nose_vel") for i in [1,2,3,4]],
    "Middle Tail Movement", 
    *[pl.col("Middle Tail Movement").shift(i).alias(f"lagged_{i}_mid_tail_mov") for i in [1,2,3,4]],
    "Middle Tail Velocity", 
    *[pl.col("Middle Tail Velocity").shift(i).alias(f"lagged_{i}_mid_tail_vel") for i in [1,2,3,4]],
    "Current Coeff", 
    *[pl.col("Current Coeff").shift(i).alias(f"lagged_{i}_cur_coeff") for i in [1,2,3,4]],
    "Lagged 2 Coeff", 
    *[pl.col("Lagged 2 Coeff").shift(i).alias(f"lagged_{i}_coeff_2") for i in [1,2,3,4]],
    "Current Coeff Time Proportional", 
    *[pl.col("Current Coeff Time Proportional").shift(i).alias(f"lagged_{i}_cur_coeff_time_prop") for i in [1,2,3,4]],
    "Lagged 2 Time Proportional", 
    *[pl.col("Lagged 2 Time Proportional").shift(i).alias(f"lagged_{i}_coeff_2_time_prop") for i in [1,2,3,4]],
    "Choice Output", 
    *[pl.col("Choice Output").shift(i).alias(f"lagged_{i}_choice_ago") for i in [1,2,3,4]]
)

# %%
lagged_df_everything_stats_sa190m1
# Out:
# shape: (29, 85)
# ┌───────────┬──────────────┬──────────────┬──────────────┬───┬──────────────┬──────────────┬─────────────┬─────────────┐
# │ Duration  ┆ lagged_1_dur ┆ lagged_2_dur ┆ lagged_3_dur ┆ … ┆ lagged_1_cho ┆ lagged_2_cho ┆ lagged_3_ch ┆ lagged_4_ch │
# │ ---       ┆ ation        ┆ ation        ┆ ation        ┆   ┆ ice_ago      ┆ ice_ago      ┆ oice_ago    ┆ oice_ago    │
# │ f64       ┆ ---          ┆ ---          ┆ ---          ┆   ┆ ---          ┆ ---          ┆ ---         ┆ ---         │
# │           ┆ f64          ┆ f64          ┆ f64          ┆   ┆ i64          ┆ i64          ┆ i64         ┆ i64         │
# ╞═══════════╪══════════════╪══════════════╪══════════════╪═══╪══════════════╪══════════════╪═════════════╪═════════════╡
# │ 10.733333 ┆ null         ┆ null         ┆ null         ┆ … ┆ null         ┆ null         ┆ null        ┆ null        │
# ...

# %%
lagged_df_everything_stats_sa190m1 = lagged_df_everything_stats_sa190m1.drop_nulls()

# %%
lagged_df_everything_stats_sa190m1.write_csv('lagged_df_everything_stats_sa190m1.csv')

# %%
lagged_df_everything_stats_sa190m1 = pd.read_csv('lagged_df_everything_stats_sa190m1.csv')

# %%
lagged_df_everything_stats_sa190m1['Choice Output'] = lagged_df_everything_stats_sa190m1['Choice Output'].astype("string")
lagged_df_everything_stats_sa190m1['lagged_1_choice_ago'] = lagged_df_everything_stats_sa190m1['lagged_1_choice_ago'].astype("string")
lagged_df_everything_stats_sa190m1['lagged_2_choice_ago'] = lagged_df_everything_stats_sa190m1['lagged_2_choice_ago'].astype("string")
lagged_df_everything_stats_sa190m1['lagged_3_choice_ago'] = lagged_df_everything_stats_sa190m1['lagged_3_choice_ago'].astype("string")
lagged_df_everything_stats_sa190m1['lagged_4_choice_ago'] = lagged_df_everything_stats_sa190m1['lagged_4_choice_ago'].astype("string")

# %%
sns.catplot(data=lagged_df_everything_stats_sa190m1, x="lagged_1_duration", y="Choice Output", kind="box")

# %%
df_sa88m2_pls = pl.read_csv('sa88m2_021225_everything_stats.csv')

# %%
summary_sa88m2 = df_sa88m2_pls.select(cs.numeric()).describe()

# %%
summary_sa88m2
# Out:
# shape: (9, 19)
# ┌────────────┬───────────┬───────────┬──────────┬───┬──────────┬──────────────────┬──────────────────┬─────────────────┐
# │ statistic  ┆           ┆ Duration  ┆ Entry    ┆ … ┆ Lagged 2 ┆ Current Coeff    ┆ Lagged 2 Time    ┆ Choice Output   │
# │ ---        ┆ ---       ┆ ---       ┆ Latency  ┆   ┆ Coeff    ┆ Time P…          ┆ Propor…          ┆ ---             │
# │ str        ┆ f64       ┆ f64       ┆ ---      ┆   ┆ ---      ┆ ---              ┆ ---              ┆ f64             │
# │            ┆           ┆           ┆ f64      ┆   ┆ f64      ┆ f64              ┆ f64              ┆                 │
# ╞════════════╪═══════════╪═══════════╪══════════╪═══╪══════════╪══════════════════╪══════════════════╪═════════════════╡
# │ count      ┆ 42.0      ┆ 42.0      ┆ 42.0     ┆ … ┆ 42.0     ┆ 42.0             ┆ 42.0             ┆ 42.0            │
# ...

# %%
'''
create lagging columns
'''

lagged_df_everything_stats_sa88m2 = df_sa88m2_pls.select(
    "Duration", 
    *[pl.col("Duration").shift(i).alias(f"lagged_{i}_duration") for i in [1,2,3,4]],
    "Entry Latency", 
    *[pl.col("Entry Latency").shift(i).alias(f"lagged_{i}_entry_lat") for i in [1,2,3,4]],
    "Exit Latency", 
    *[pl.col("Exit Latency").shift(i).alias(f"lagged_{i}_exit_lat") for i in [1,2,3,4]], 
    "Arm Nose Movement", 
    *[pl.col("Arm Nose Movement").shift(i).alias(f"lagged_{i}_arm_nose_mov") for i in [1,2,3,4]],
    "Arm Nose Velocity", 
    *[pl.col("Arm Nose Velocity").shift(i).alias(f"lagged_{i}_arm_nose_vel") for i in [1,2,3,4]],
    "Arm Tail Movement", 
    *[pl.col("Arm Tail Movement").shift(i).alias(f"lagged_{i}_arm_tail_mov") for i in [1,2,3,4]],
    "Arm Tail Velocity", 
    *[pl.col("Arm Tail Velocity").shift(i).alias(f"lagged_{i}_arm_tail_vel") for i in [1,2,3,4]],
    "Middle Duration", 
    *[pl.col("Middle Duration").shift(i).alias(f"lagged_{i}_mid_duration") for i in [1,2,3,4]],
    "Middle Nose Movement", 
    *[pl.col("Middle Nose Movement").shift(i).alias(f"lagged_{i}_mid_nose_mov") for i in [1,2,3,4]],
    "Middle Nose Velocity", 
    *[pl.col("Middle Nose Velocity").shift(i).alias(f"lagged_{i}_mid_nose_vel") for i in [1,2,3,4]],
    "Middle Tail Movement", 
    *[pl.col("Middle Tail Movement").shift(i).alias(f"lagged_{i}_mid_tail_mov") for i in [1,2,3,4]],
    "Middle Tail Velocity", 
    *[pl.col("Middle Tail Velocity").shift(i).alias(f"lagged_{i}_mid_tail_vel") for i in [1,2,3,4]],
    "Current Coeff", 
    *[pl.col("Current Coeff").shift(i).alias(f"lagged_{i}_cur_coeff") for i in [1,2,3,4]],
    "Lagged 2 Coeff", 
    *[pl.col("Lagged 2 Coeff").shift(i).alias(f"lagged_{i}_coeff_2") for i in [1,2,3,4]],
    "Current Coeff Time Proportional", 
    *[pl.col("Current Coeff Time Proportional").shift(i).alias(f"lagged_{i}_cur_coeff_time_prop") for i in [1,2,3,4]],
    "Lagged 2 Time Proportional", 
    *[pl.col("Lagged 2 Time Proportional").shift(i).alias(f"lagged_{i}_coeff_2_time_prop") for i in [1,2,3,4]],
    "Choice Output", 
    *[pl.col("Choice Output").shift(i).alias(f"lagged_{i}_choice_ago") for i in [1,2,3,4]]
)

# %%
lagged_df_everything_stats_sa88m2
# Out:
# shape: (42, 85)
# ┌───────────┬──────────────┬──────────────┬──────────────┬───┬──────────────┬──────────────┬─────────────┬─────────────┐
# │ Duration  ┆ lagged_1_dur ┆ lagged_2_dur ┆ lagged_3_dur ┆ … ┆ lagged_1_cho ┆ lagged_2_cho ┆ lagged_3_ch ┆ lagged_4_ch │
# │ ---       ┆ ation        ┆ ation        ┆ ation        ┆   ┆ ice_ago      ┆ ice_ago      ┆ oice_ago    ┆ oice_ago    │
# │ f64       ┆ ---          ┆ ---          ┆ ---          ┆   ┆ ---          ┆ ---          ┆ ---         ┆ ---         │
# │           ┆ f64          ┆ f64          ┆ f64          ┆   ┆ i64          ┆ i64          ┆ i64         ┆ i64         │
# ╞═══════════╪══════════════╪══════════════╪══════════════╪═══╪══════════════╪══════════════╪═════════════╪═════════════╡
# │ 21.233333 ┆ null         ┆ null         ┆ null         ┆ … ┆ null         ┆ null         ┆ null        ┆ null        │
# ...

# %%
lagged_df_everything_stats_sa88m2 = lagged_df_everything_stats_sa88m2.drop_nulls()

# %%
lagged_df_everything_stats_sa88m2.write_csv('lagged_df_everything_stats_sa88m2.csv')

# %%
lagged_df_everything_stats_sa88m2 = pd.read_csv('lagged_df_everything_stats_sa88m2.csv')

# %%
lagged_df_everything_stats_sa88m2['Choice Output'] = lagged_df_everything_stats_sa88m2['Choice Output'].astype("string")
lagged_df_everything_stats_sa88m2['lagged_1_choice_ago'] = lagged_df_everything_stats_sa88m2['lagged_1_choice_ago'].astype("string")
lagged_df_everything_stats_sa88m2['lagged_2_choice_ago'] = lagged_df_everything_stats_sa88m2['lagged_2_choice_ago'].astype("string")
lagged_df_everything_stats_sa88m2['lagged_3_choice_ago'] = lagged_df_everything_stats_sa88m2['lagged_3_choice_ago'].astype("string")
lagged_df_everything_stats_sa88m2['lagged_4_choice_ago'] = lagged_df_everything_stats_sa88m2['lagged_4_choice_ago'].astype("string")

# %%
sns.catplot(data=lagged_df_everything_stats_sa88m2, x="lagged_1_mid_duration", y="Choice Output", kind="box")

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
lagged_scaled_data_sa190m1 = lagged_df_everything_stats_sa190m1

# %%
lagged_scaled_data_sa190m1[lagged_scaled_data_sa190m1.columns[:80]] = scaler.fit_transform(lagged_scaled_data_sa190m1[lagged_scaled_data_sa190m1.columns[:80]])

# %%
type(lagged_scaled_data_sa190m1)
# Out:
# pandas.core.frame.DataFrame

# %%
lagged_scaled_data_sa190m1['mouse'] = 'sa190m1'

# %%
lagged_scaled_data_sa190m1
# Out:
#     Duration  lagged_1_duration  lagged_2_duration  lagged_3_duration  \
# 0   0.219231           0.346154           1.000000           0.461864
# 1   0.016667           0.219231           0.374480           1.000000
# 2   0.146154           0.016667           0.237171           0.362994
# 3   0.137179           0.146154           0.018031           0.223164
# 4   0.144872           0.137179           0.158114           0.000000
# 5   0.085897           0.144872           0.148405           0.142655
# 6   0.094872           0.085897           0.156727           0.132768
# 7   0.311538           0.094872           0.092926           0.141243
# 8   0.125641           0.311538           0.102635           0.076271
# 9   0.170513           0.125641           0.337032           0.086158
# 10  0.216667           0.170513           0.135922           0.324859
# 11  0.208974           0.216667           0.184466           0.120056
# ...

# %%
lagged_scaled_data_sa88m2 = lagged_df_everything_stats_sa88m2

# %%
lagged_scaled_data_sa88m2[lagged_scaled_data_sa88m2.columns[:80]] = scaler.fit_transform(lagged_scaled_data_sa88m2[lagged_scaled_data_sa88m2.columns[:80]])

# %%
lagged_scaled_data_sa88m2
# Out:
#     Duration  lagged_1_duration  lagged_2_duration  lagged_3_duration  \
# 0   0.681529           0.528662           0.579618           1.000000
# 1   0.547771           0.681529           0.528662           0.515581
# 2   0.601911           0.547771           0.681529           0.470255
# 3   0.585987           0.601911           0.547771           0.606232
# 4   0.442675           0.585987           0.601911           0.487252
# 5   0.528662           0.442675           0.585987           0.535411
# 6   0.372611           0.528662           0.442675           0.521246
# 7   0.522293           0.372611           0.528662           0.393768
# 8   0.359873           0.522293           0.372611           0.470255
# 9   0.490446           0.359873           0.522293           0.331445
# 10  1.000000           0.490446           0.359873           0.464589
# 11  0.799363           1.000000           0.490446           0.320113
# ...

# %%
sns.catplot(data=lagged_scaled_data_sa190m1, x="lagged_1_duration", y="Choice Output", kind="box")

# %%
sns.catplot(data=lagged_scaled_data_sa88m2, x="lagged_1_duration", y="Choice Output", kind="box")

# %%
sns.lineplot(lagged_scaled_data_sa190m1['Duration'])
# Out:
# C:\Users\Josue Regalado\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Josue Regalado\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: ylabel='Duration'>

# %%
sns.lineplot(lagged_scaled_data_sa88m2['Duration'])
# Out:
# C:\Users\Josue Regalado\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Josue Regalado\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: ylabel='Duration'>

# %%
lagged_scaled_data_sa88m2['mouse'] = 'sa88m2'

# %%
lagged_scaled_data_sa88m2
# Out:
#     Duration  lagged_1_duration  lagged_2_duration  lagged_3_duration  \
# 0   0.681529           0.528662           0.579618           1.000000
# 1   0.547771           0.681529           0.528662           0.515581
# 2   0.601911           0.547771           0.681529           0.470255
# 3   0.585987           0.601911           0.547771           0.606232
# 4   0.442675           0.585987           0.601911           0.487252
# 5   0.528662           0.442675           0.585987           0.535411
# 6   0.372611           0.528662           0.442675           0.521246
# 7   0.522293           0.372611           0.528662           0.393768
# 8   0.359873           0.522293           0.372611           0.470255
# 9   0.490446           0.359873           0.522293           0.331445
# 10  1.000000           0.490446           0.359873           0.464589
# 11  0.799363           1.000000           0.490446           0.320113
# ...

# %%
df_added = pd.concat([lagged_scaled_data_sa88m2,lagged_scaled_data_sa190m1])

# %%
df_added
# Out:
#     Duration  lagged_1_duration  lagged_2_duration  lagged_3_duration  \
# 0   0.681529           0.528662           0.579618           1.000000
# 1   0.547771           0.681529           0.528662           0.515581
# 2   0.601911           0.547771           0.681529           0.470255
# 3   0.585987           0.601911           0.547771           0.606232
# 4   0.442675           0.585987           0.601911           0.487252
# ..       ...                ...                ...                ...
# 20  0.298718           0.355128           0.690707           0.137006
# 21  0.379487           0.298718           0.384189           0.685028
# 22  0.000000           0.379487           0.323162           0.372881
# 23  1.000000           0.000000           0.410541           0.310734
# 24  0.511538           1.000000           0.000000           0.399718
#
#     lagged_4_duration  Entry Latency  lagged_1_entry_lat  lagged_2_entry_lat  \
# ...

# %%
sns.catplot(data=df_added, x="Duration", y="Choice Output", kind="box")

# %%
sns.displot(data=df_added, x="Duration", kind="kde")
sns.displot(data=df_added, x="Entry Latency", kind="kde")
# Out:
# C:\Users\Josue Regalado\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Josue Regalado\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.histplot(df_added['Choice Output'], bins = 5, discrete = True)
# Out:
# C:\Users\Josue Regalado\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Choice Output', ylabel='Count'>

# %%
sns.histplot(data = df_added, x = "Duration", hue = "mouse", bins = 20)
# Out:
# C:\Users\Josue Regalado\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Duration', ylabel='Count'>

# %%
sns.histplot(data = df_added, x = "Choice Output", hue = "mouse", bins = 20, multiple = "stack")
# Out:
# C:\Users\Josue Regalado\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Choice Output', ylabel='Count'>

# %%
df_added.columns
# Out:
# Index(['Duration', 'lagged_1_duration', 'lagged_2_duration',
#        'lagged_3_duration', 'lagged_4_duration', 'Entry Latency',
#        'lagged_1_entry_lat', 'lagged_2_entry_lat', 'lagged_3_entry_lat',
#        'lagged_4_entry_lat', 'Exit Latency', 'lagged_1_exit_lat',
#        'lagged_2_exit_lat', 'lagged_3_exit_lat', 'lagged_4_exit_lat',
#        'Arm Nose Movement', 'lagged_1_arm_nose_mov', 'lagged_2_arm_nose_mov',
#        'lagged_3_arm_nose_mov', 'lagged_4_arm_nose_mov', 'Arm Nose Velocity',
#        'lagged_1_arm_nose_vel', 'lagged_2_arm_nose_vel',
#        'lagged_3_arm_nose_vel', 'lagged_4_arm_nose_vel', 'Arm Tail Movement',
#        'lagged_1_arm_tail_mov', 'lagged_2_arm_tail_mov',
#        'lagged_3_arm_tail_mov', 'lagged_4_arm_tail_mov', 'Arm Tail Velocity',
#        'lagged_1_arm_tail_vel', 'lagged_2_arm_tail_vel',
#        'lagged_3_arm_tail_vel', 'lagged_4_arm_tail_vel', 'Middle Duration',
#        'lagged_1_mid_duration', 'lagged_2_mid_duration',
# ...

# %%
sns.histplot(data = df_added, x = "lagged_1_mid_nose_vel", hue = "mouse", bins = 30, multiple = "stack")
# Out:
# C:\Users\Josue Regalado\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='lagged_1_mid_nose_vel', ylabel='Count'>

# %%
sns.scatterplot(data = df_added, x = "lagged_1_arm_nose_mov", y = "Choice Output", hue = "mouse")
# Out:
# <Axes: xlabel='lagged_1_arm_nose_mov', ylabel='Choice Output'>

# %%
sns.scatterplot(data = df_added, x = "lagged_1_mid_nose_mov", y = "Choice Output", hue = "mouse")
# Out:
# <Axes: xlabel='lagged_1_mid_nose_mov', ylabel='Choice Output'>

# %%
sns.scatterplot(data = df_added, x = "Arm Nose Movement", y = "Choice Output", hue = "mouse")
# Out:
# <Axes: xlabel='Arm Nose Movement', ylabel='Choice Output'>

# %%
sns.scatterplot(data = df_added, x = "Middle Nose Movement", y = "Choice Output", hue = "mouse")
# Out:
# <Axes: xlabel='Middle Nose Movement', ylabel='Choice Output'>
